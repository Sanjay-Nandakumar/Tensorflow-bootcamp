# %% [markdown]
# Pandas Crash Course

# %%
import pandas as pd
#Series
mylist = [1,2,3,4,5]
ser = pd.Series(mylist)
ser
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
#Labels
labels =['a','b','c','d','e']
ser = pd.Series(mylist,labels)
ser
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64

# %%
ser = pd.Series(data=[100,200,300],index=["one","two","three"])
ser
# Out:
# one      100
# two      200
# three    300
# dtype: int64

# %%
ser["one"]
# Out:
# 100

# %%
ser["one"] + ser["two"]
# Out:
# 300

# %%
ser1 = pd.Series(data=[100,200,300],index=["one","two","three"])
ser2 = pd.Series(data=[1000,2000,3000],index=["one","two","three"])
ser1 + ser2
# Out:
# one      1100
# two      2200
# three    3300
# dtype: int64

# %%
#Dataframe
import numpy as np
data = np.random.randint(1,25,25).reshape(5,5)
data
# Out:
# array([[14, 13, 10, 24,  6],
#        [ 7, 20, 15,  3, 18],
#        [ 1,  7,  7, 18, 21],
#        [22, 12,  1,  1, 10],
#        [12,  6, 24, 11, 18]])

# %%
ind =["row1","row2","row3","row4","row5"]
col =["col1","col2","col3","col4","col5" ]
df = pd.DataFrame(data,index=ind,columns=col)
df
# Out:
#       col1  col2  col3  col4  col5
# row1    14    13    10    24     6
# row2     7    20    15     3    18
# row3     1     7     7    18    21
# row4    22    12     1     1    10
# row5    12     6    24    11    18

# %%
df["col1"]
# Out:
# row1    14
# row2     7
# row3     1
# row4    22
# row5    12
# Name: col1, dtype: int64

# %%
type(df["col1"])
# Out:
# pandas.core.series.Series

# %%
df[["col1","col2"]]
# Out:
#       col1  col2
# row1    14    13
# row2     7    20
# row3     1     7
# row4    22    12
# row5    12     6

# %%
df["new"] = df["col1"] + df["col2"]

# %%
df
# Out:
#       col1  col2  col3  col4  col5  new
# row1    14    13    10    24     6   27
# row2     7    20    15     3    18   27
# row3     1     7     7    18    21    8
# row4    22    12     1     1    10   34
# row5    12     6    24    11    18   18

# %%
df.drop("new",axis=1)
# Out:
#       col1  col2  col3  col4  col5
# row1    14    13    10    24     6
# row2     7    20    15     3    18
# row3     1     7     7    18    21
# row4    22    12     1     1    10
# row5    12     6    24    11    18

# %%
df.loc["row1"]
# Out:
# col1    14
# col2    13
# col3    10
# col4    24
# col5     6
# new     27
# Name: row1, dtype: int64

# %%
df.loc[["row1","row2"]]
# Out:
#       col1  col2  col3  col4  col5  new
# row1    14    13    10    24     6   27
# row2     7    20    15     3    18   27

# %%
df.iloc[0:3]
# Out:
#       col1  col2  col3  col4  col5  new
# row1    14    13    10    24     6   27
# row2     7    20    15     3    18   27
# row3     1     7     7    18    21    8

# %%
df = df.drop("row4")

# %%
df
# Out:
#       col1  col2  col3  col4  col5  new
# row1    14    13    10    24     6   27
# row2     7    20    15     3    18   27
# row3     1     7     7    18    21    8
# row5    12     6    24    11    18   18

# %%
df >10
# Out:
#        col1   col2   col3   col4   col5    new
# row1   True   True  False   True  False   True
# row2  False   True   True  False   True   True
# row3  False  False  False   True   True  False
# row5   True  False   True   True   True   True

# %%
df [df>10]
# Out:
#       col1  col2  col3  col4  col5   new
# row1  14.0  13.0   NaN  24.0   NaN  27.0
# row2   NaN  20.0  15.0   NaN  18.0  27.0
# row3   NaN   NaN   NaN  18.0  21.0   NaN
# row5  12.0   NaN  24.0  11.0  18.0  18.0

# %%
df["col1"] >10
# Out:
# row1     True
# row2    False
# row3    False
# row5     True
# Name: col1, dtype: bool

# %%
df [ df["col1"] > 10 ]
# Out:
#       col1  col2  col3  col4  col5  new
# row1    14    13    10    24     6   27
# row5    12     6    24    11    18   18

# %%
df.reset_index()
# Out:
#   index  col1  col2  col3  col4  col5  new
# 0  row1    14    13    10    24     6   27
# 1  row2     7    20    15     3    18   27
# 2  row3     1     7     7    18    21    8
# 3  row5    12     6    24    11    18   18

# %%
df.loc["row1"]
# Out:
# col1    14
# col2    13
# col3    10
# col4    24
# col5     6
# new     27
# Name: row1, dtype: int64

# %%
df.iloc[0]
# Out:
# col1    14
# col2    13
# col3    10
# col4    24
# col5     6
# new     27
# Name: row1, dtype: int64

# %%
df=df.reset_index()

# %%
df
# Out:
#   index  col1  col2  col3  col4  col5  new
# 0  row1    14    13    10    24     6   27
# 1  row2     7    20    15     3    18   27
# 2  row3     1     7     7    18    21    8
# 3  row5    12     6    24    11    18   18

# %%
df.set_index("new")
# Out:
#     index  col1  col2  col3  col4  col5
# new
# 27   row1    14    13    10    24     6
# 27   row2     7    20    15     3    18
# 8    row3     1     7     7    18    21
# 18   row5    12     6    24    11    18

# %%
df.columns
# Out:
# Index(['index', 'col1', 'col2', 'col3', 'col4', 'col5', 'new'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   index   4 non-null      object
#  1   col1    4 non-null      int64
#  2   col2    4 non-null      int64
#  3   col3    4 non-null      int64
#  4   col4    4 non-null      int64
#  5   col5    4 non-null      int64
#  6   new     4 non-null      int64
# dtypes: int64(6), object(1)
# memory usage: 352.0+ bytes

# %%
df.describe()
# Out:
#             col1       col2       col3       col4       col5        new
# count   4.000000   4.000000   4.000000   4.000000   4.000000   4.000000
# mean    8.500000  11.500000  14.000000  14.000000  15.750000  20.000000
# std     5.802298   6.454972   7.438638   9.055385   6.652067   9.055385
# min     1.000000   6.000000   7.000000   3.000000   6.000000   8.000000
# 25%     5.500000   6.750000   9.250000   9.000000  15.000000  15.500000
# 50%     9.500000  10.000000  12.500000  14.500000  18.000000  22.500000
# 75%    12.500000  14.750000  17.250000  19.500000  18.750000  27.000000
# max    14.000000  20.000000  24.000000  24.000000  21.000000  27.000000

# %%
ind =["row1","row2","row3","row4","row5"]
col =["col1","col2","col3","col4","col5" ]
df = pd.DataFrame(data,index=ind,columns=col)
df
# Out:
#       col1  col2  col3  col4  col5
# row1    14    13    10    24     6
# row2     7    20    15     3    18
# row3     1     7     7    18    21
# row4    22    12     1     1    10
# row5    12     6    24    11    18

# %%
df = df.replace(14,np.nan)
df = df.replace(15,np.nan)
df = df.replace(18,np.nan)
df = df.replace(12,np.nan)

# %%
df
# Out:
#       col1  col2  col3  col4  col5
# row1   NaN  13.0  10.0  24.0   6.0
# row2   7.0  20.0   NaN   3.0   NaN
# row3   1.0   7.0   7.0   NaN  21.0
# row4  22.0   NaN   1.0   1.0  10.0
# row5   NaN   6.0  24.0  11.0   NaN

# %%
df.dropna(axis=0)
# Out:
# Empty DataFrame
# Columns: [col1, col2, col3, col4, col5]
# Index: []

# %%
df
# Out:
#       col1  col2  col3  col4  col5
# row1   NaN  13.0  10.0  24.0   6.0
# row2   7.0  20.0   NaN   3.0   NaN
# row3   1.0   7.0   7.0   NaN  21.0
# row4  22.0   NaN   1.0   1.0  10.0
# row5   NaN   6.0  24.0  11.0   NaN

# %%
df.dropna(axis=1)
# Out:
# Empty DataFrame
# Columns: []
# Index: [row1, row2, row3, row4, row5]

# %%
df
# Out:
#       col1  col2  col3  col4  col5
# row1   NaN  13.0  10.0  24.0   6.0
# row2   7.0  20.0   NaN   3.0   NaN
# row3   1.0   7.0   7.0   NaN  21.0
# row4  22.0   NaN   1.0   1.0  10.0
# row5   NaN   6.0  24.0  11.0   NaN

# %%
df.fillna(value="Fill value")
# Out:
#             col1        col2        col3        col4        col5
# row1  Fill value          13          10          24           6
# row2           7          20  Fill value           3  Fill value
# row3           1           7           7  Fill value          21
# row4          22  Fill value           1           1          10
# row5  Fill value           6          24          11  Fill value

# %%
df
# Out:
#       col1  col2  col3  col4  col5
# row1   NaN  13.0  10.0  24.0   6.0
# row2   7.0  20.0   NaN   3.0   NaN
# row3   1.0   7.0   7.0   NaN  21.0
# row4  22.0   NaN   1.0   1.0  10.0
# row5   NaN   6.0  24.0  11.0   NaN

# %%
df["col1"].fillna(0)
# Out:
# row1     0.0
# row2     7.0
# row3     1.0
# row4    22.0
# row5     0.0
# Name: col1, dtype: float64

# %%
df.fillna(df.mean())
# Out:
#       col1  col2  col3   col4       col5
# row1  10.0  13.0  10.0  24.00   6.000000
# row2   7.0  20.0  10.5   3.00  12.333333
# row3   1.0   7.0   7.0   9.75  21.000000
# row4  22.0  11.5   1.0   1.00  10.000000
# row5  10.0   6.0  24.0  11.00  12.333333

# %%
data = pd.read_csv("/titanic.csv")

# %%
data.head(10)
# Out:
#    PassengerId  Pclass  ... Cabin Embarked
# 0          892       3  ...   NaN        Q
# 1          893       3  ...   NaN        S
# 2          894       2  ...   NaN        Q
# 3          895       3  ...   NaN        S
# 4          896       3  ...   NaN        S
# 5          897       3  ...   NaN        S
# 6          898       3  ...   NaN        Q
# 7          899       2  ...   NaN        S
# 8          900       3  ...   NaN        C
# 9          901       3  ...   NaN        S
#
# [10 rows x 11 columns]

# %%
data.groupby("Pclass").mean()["Age"]
# Out:
# Pclass
# 1    40.918367
# 2    28.777500
# 3    24.027945
# Name: Age, dtype: float64

# %%
data.groupby("Pclass").mean().sort_index(ascending=False)
# Out:
#         PassengerId        Age     SibSp     Parch       Fare
# Pclass
# 3       1094.178899  24.027945  0.463303  0.417431  12.459678
# 2       1117.935484  28.777500  0.376344  0.344086  22.202104
# 1       1098.224299  40.918367  0.476636  0.383178  94.280297

# %%
data.groupby("Pclass").describe()
# Out:
#        PassengerId                           ...     Fare
#              count         mean         std  ...      50%    75%       max
# Pclass                                       ...
# 1            107.0  1098.224299  126.234232  ...  60.0000  134.5  512.3292
# 2             93.0  1117.935484  115.386289  ...  15.7500   26.0   73.5000
# 3            218.0  1094.178899  120.188830  ...   7.8958   14.4   69.5500
#
# [3 rows x 40 columns]

# %%
data.groupby("Pclass").describe().transpose()
# Out:
# Pclass                       1            2            3
# PassengerId count   107.000000    93.000000   218.000000
#             mean   1098.224299  1117.935484  1094.178899
#             std     126.234232   115.386289   120.188830
#             min     903.000000   894.000000   892.000000
#             25%     979.000000  1035.000000   994.250000
#             50%    1094.000000  1122.000000  1091.500000
#             75%    1211.500000  1221.000000  1191.750000
#             max    1306.000000  1298.000000  1309.000000
# Age         count    98.000000    88.000000   146.000000
#             mean     40.918367    28.777500    24.027945
#             std      13.956799    12.943458    10.537105
#             min       6.000000     0.920000     0.170000
#             25%      30.000000    21.000000    18.500000
#             50%      42.000000    26.500000    24.000000
#             75%      50.750000    35.250000    29.750000
# ...

# %%
df["col1"].unique()
# Out:
# array([nan,  7.,  1., 22.])

# %%
df["col1"].nunique()
# Out:
# 3

# %%
df["col1"].value_counts()
# Out:
# 22.0    1
# 1.0     1
# 7.0     1
# Name: col1, dtype: int64

# %%
df=df.replace(np.nan,0)
df
# Out:
#       col1  col2  col3  col4  col5
# row1   0.0  13.0  10.0  24.0   6.0
# row2   7.0  20.0   0.0   3.0   0.0
# row3   1.0   7.0   7.0   0.0  21.0
# row4  22.0   0.0   1.0   1.0  10.0
# row5   0.0   6.0  24.0  11.0   0.0

# %%
mymap={0:1,7:2,1:3,2:4,0:5 }
df["new"] = df["col1"].map(mymap)

# %%
df
# Out:
#       col1  col2  col3  col4  col5  new
# row1   0.0  13.0  10.0  24.0   6.0  5.0
# row2   7.0  20.0   0.0   3.0   0.0  2.0
# row3   1.0   7.0   7.0   0.0  21.0  3.0
# row4  22.0   0.0   1.0   1.0  10.0  NaN
# row5   0.0   6.0  24.0  11.0   0.0  5.0

# %%
df.sort_values("col1")
# Out:
#       col1  col2  col3  col4  col5  new
# row1   0.0  13.0  10.0  24.0   6.0  5.0
# row5   0.0   6.0  24.0  11.0   0.0  5.0
# row3   1.0   7.0   7.0   0.0  21.0  3.0
# row2   7.0  20.0   0.0   3.0   0.0  2.0
# row4  22.0   0.0   1.0   1.0  10.0  NaN

# %%
data.head(5)
# Out:
#    PassengerId  Pclass  ... Cabin Embarked
# 0          892       3  ...   NaN        Q
# 1          893       3  ...   NaN        S
# 2          894       2  ...   NaN        Q
# 3          895       3  ...   NaN        S
# 4          896       3  ...   NaN        S
#
# [5 rows x 11 columns]

# %%
pd.get_dummies(data,"Sex")
# Out:
#      PassengerId  Pclass   Age  SibSp  ...  Sex_G6  Sex_C  Sex_Q  Sex_S
# 0            892       3  34.5      0  ...       0      0      1      0
# 1            893       3  47.0      1  ...       0      0      0      1
# 2            894       2  62.0      0  ...       0      0      1      0
# 3            895       3  27.0      0  ...       0      0      0      1
# 4            896       3  22.0      1  ...       0      0      0      1
# ..           ...     ...   ...    ...  ...     ...    ...    ...    ...
# 413         1305       3   NaN      0  ...       0      0      0      1
# 414         1306       1  39.0      0  ...       0      1      0      0
# 415         1307       3  38.5      0  ...       0      0      0      1
# 416         1308       3   NaN      0  ...       0      0      0      1
# 417         1309       3   NaN      1  ...       0      1      0      0
#
# [418 rows x 868 columns]
